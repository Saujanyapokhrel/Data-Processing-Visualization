# %% [markdown]
# <a href="https://colab.research.google.com/github/Saujanyapokhrel/Data-Processing-Visualization/blob/main/Quiz23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![tumblr_qemlmmsPHe1sgh0voo1_1280 2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #https://viz.wtf/post/625905143078141953/i-dont-even-know-where-to-begin-with-this-one

# %% [markdown]
# The bar chart above shows the number of COVID cases confirmed in 5 days in Florida. We can see that the number of cases are increasing since the day one and decreases only in the last day but the graph tells us a different story. The day with the most number cases has been confirmed has the lowest representation and on the day with the lowest number of confirmed cases, the chart shows the second highest representation. This bar chart is a good example of sophistication as it does not clearly gives the correct information and you have to spend more time looking at it to get the proper information.
