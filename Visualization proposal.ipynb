# %% [markdown]
# <a href="https://colab.research.google.com/github/Saujanyapokhrel/Data-Processing-Visualization/blob/main/Visualization%20proposal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Saujanya Pokhrel
# #Recent Visualization Proposal

# %% [markdown]
# ![Screen Shot 2022-04-24 at 2.07.08 PM.png](data:image/png;base64,...)
#
# ## I have considered the data from the premier leageu 2021/2022 season for the visualization project. I have considered this topic because it is an ongoing season with 4 games left that will be played over the course of 4-5 weeks and premier league is one of the biggest leagues in the soccer.
#
# ## since the premier league is one of the mostly watched leagues, there are a lot of sources to get data from each game. A lot of data can be obtained form the premier league website and many other sports websites to visualize. I will specifically be visualizing the data for the top four team and the bottom three teams that will be relegated this year. A lot of data between the top four and bottom three teams suchas goals score/against, yellow/redcards receive, number of assists, heatmap of the team can be visualized.

# %% [markdown]
# ##While doing this project I will be learning different methods of data collection and since I follow premier league and watch all games, I will be able to compare it to the data that I come across and will be able to judge it whether it is right or it is misleading. Other improtant aspect that I will learn from visualizing this topic is whether the data provided will give us a clear understanding of the dataset just looking at the visualization.
#
# ![image.png](data:image/png;base64,...)
