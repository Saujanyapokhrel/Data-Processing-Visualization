# %% [markdown]
# <a href="https://colab.research.google.com/github/Saujanyapokhrel/Data-Processing-Visualization/blob/main/Recreate%20Masters%20proposal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Saujanya Pokhrel
# # Recreating Masters Proposal

# %% [markdown]
# ##For recreating masters I have decided to recreate a bar chart that shows the 10 most valuable brands in the world.
# # For this I have used the following.
# #Visualization link:
# #https://www.marketingcharts.com/brand-related/top-brands-118855
# #Dataset link:
# #https://en.wikipedia.org/wiki/List_of_most_valuable_brands
# #Visualization Image:
# ![Screen Shot 2022-04-24 at 9.06.06 PM.png](data:image/png;base64,...)

# %% [markdown]
# #Excellence
# ##The visualization shows the top 10 global brands by millions based on year - over - year change in 2021.The bar chart is easy to understand as it is color coded as a single color and presented in a simlpe way everyone can understand.
#
# #Description
# ##The charthas a title and on the left side of the chart the name of the brands have been mentioned which makes it easy for us to know which brand had year-over-year change the most. The amounts are mentioned along side the chart and even represented by percentage at the other end so it becomes easy to understand.
#
# #Hardships
# ##Since there is no proper dataset for the visualization, the data should be extracted from a different source and while doing the visualization, the final product of the data may not resemble the exact image from the visualization but will be somehow similar.
